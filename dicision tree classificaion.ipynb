# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
data= pd.read_csv("https://raw.githubusercontent.com/shrikant-temburwar/Wine-Quality-Dataset/master/winequality-red.csv",sep = ';')

# %%
df = data.copy()

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df["quality"].value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
df["quality"].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# fixed acidity          7.90000   9.200000   15.90000
# volatile acidity       0.52000   0.640000    1.58000
# citric acid            0.26000   0.420000    1.00000
# residual sugar         2.20000   2.600000   15.50000
# chlorides              0.07900   0.090000    0.61100
# free sulfur dioxide   14.00000  21.000000   72.00000
# total sulfur dioxide  38.00000  62.000000  289.00000
# density                0.99675   0.997835    1.00369
# pH                     3.31000   3.400000    4.01000
# sulphates              0.62000   0.730000    2.00000
# alcohol               10.20000  11.100000   14.90000
# quality                6.00000   6.000000    8.00000

# %%
df.duplicated().sum()
# Out:
# np.int64(240)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.shape
# Out:
# (1359, 12)

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
X= df.iloc[:, :11]

# %%
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 5      9.4

# %%
y = df.quality

# %%
y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 5    5
# Name: quality, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=45)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((1019, 11), (340, 11), (1019,), (340,))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(x_test,y_test)
# Out:
# 0.4852941176470588

# %%
from sklearn import tree
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(25,15))
#tree.plot_tree(dt, filled = True)             #before set depth
tree.plot_tree(dt, max_depth=4,filled=True)    #After set depth
# Out:
# [Text(0.4869791666666667, 0.9166666666666666, 'x[10] <= 10.525\ngini = 0.65\nsamples = 1019\nvalue = [7, 43, 423, 408, 126, 12]'),
#  Text(0.2708333333333333, 0.75, 'x[6] <= 98.5\ngini = 0.552\nsamples = 630\nvalue = [4, 27, 362, 213, 22, 2]'),
#  Text(0.37890625, 0.8333333333333333, 'True  '),
#  Text(0.16666666666666666, 0.5833333333333334, 'x[1] <= 0.405\ngini = 0.577\nsamples = 553\nvalue = [4, 26, 292, 207, 22, 2]'),
#  Text(0.08333333333333333, 0.4166666666666667, 'x[9] <= 0.585\ngini = 0.572\nsamples = 121\nvalue = [0, 1, 39, 68, 11, 2]'),
#  Text(0.041666666666666664, 0.25, 'x[8] <= 3.35\ngini = 0.492\nsamples = 39\nvalue = [0, 1, 24, 14, 0, 0]'),
#  Text(0.020833333333333332, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.0625, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.125, 0.25, 'x[7] <= 0.996\ngini = 0.514\nsamples = 82\nvalue = [0, 0, 15, 54, 11, 2]'),
#  Text(0.10416666666666667, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.14583333333333334, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.25, 0.4166666666666667, 'x[10] <= 9.85\ngini = 0.549\nsamples = 432\nvalue = [4, 25, 253, 139, 11, 0]'),
#  Text(0.20833333333333334, 0.25, 'x[5] <= 19.5\ngini = 0.497\nsamples = 274\nvalue = [3, 17, 180, 71, 3, 0]'),
#  Text(0.1875, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.22916666666666666, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.2916666666666667, 0.25, 'x[9] <= 0.525\ngini = 0.596\nsamples = 158\nvalue = [1, 8, 73, 68, 8, 0]'),
#  Text(0.2708333333333333, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.3125, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.375, 0.5833333333333334, 'x[3] <= 1.6\ngini = 0.167\nsamples = 77\nvalue = [0, 1, 70, 6, 0, 0]'),
#  Text(0.3541666666666667, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.3958333333333333, 0.4166666666666667, 'x[5] <= 70.0\ngini = 0.145\nsamples = 76\nvalue = [0, 0, 70, 6, 0, 0]'),
#  Text(0.375, 0.25, 'x[9] <= 1.175\ngini = 0.124\nsamples = 75\nvalue = [0, 0, 70, 5, 0, 0]'),
#  Text(0.3541666666666667, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.3958333333333333, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.4166666666666667, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.703125, 0.75, 'x[9] <= 0.705\ngini = 0.65\nsamples = 389\nvalue = [3.0, 16.0, 61.0, 195.0, 104.0, 10.0]'),
#  Text(0.5950520833333334, 0.8333333333333333, '  False'),
#  Text(0.5729166666666666, 0.5833333333333334, 'x[6] <= 15.5\ngini = 0.626\nsamples = 240\nvalue = [3, 16, 47, 133, 37, 4]'),
#  Text(0.5, 0.4166666666666667, 'x[2] <= 0.25\ngini = 0.753\nsamples = 65\nvalue = [3, 8, 13, 21, 19, 1]'),
#  Text(0.4583333333333333, 0.25, 'x[9] <= 0.525\ngini = 0.76\nsamples = 30\nvalue = [3, 7, 10, 7, 3, 0]'),
#  Text(0.4375, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.4791666666666667, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.5416666666666666, 0.25, 'x[8] <= 3.275\ngini = 0.622\nsamples = 35\nvalue = [0, 1, 3, 14, 16, 1]'),
#  Text(0.5208333333333334, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.5625, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.6458333333333334, 0.4166666666666667, 'x[2] <= 0.745\ngini = 0.54\nsamples = 175\nvalue = [0, 8, 34, 112, 18, 3]'),
#  Text(0.625, 0.25, 'x[1] <= 1.015\ngini = 0.527\nsamples = 172\nvalue = [0.0, 8.0, 34.0, 112.0, 15.0, 3.0]'),
#  Text(0.6041666666666666, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.6458333333333334, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.6666666666666666, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.8333333333333334, 0.5833333333333334, 'x[10] <= 12.45\ngini = 0.614\nsamples = 149\nvalue = [0, 0, 14, 62, 67, 6]'),
#  Text(0.75, 0.4166666666666667, 'x[1] <= 0.445\ngini = 0.586\nsamples = 123\nvalue = [0, 0, 12, 61, 49, 1]'),
#  Text(0.7083333333333334, 0.25, 'x[7] <= 0.995\ngini = 0.555\nsamples = 77\nvalue = [0.0, 0.0, 4.0, 32.0, 40.0, 1.0]'),
#  Text(0.6875, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.7291666666666666, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.7916666666666666, 0.25, 'x[3] <= 2.25\ngini = 0.534\nsamples = 46\nvalue = [0, 0, 8, 29, 9, 0]'),
#  Text(0.7708333333333334, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.8125, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.9166666666666666, 0.4166666666666667, 'x[7] <= 0.996\ngini = 0.476\nsamples = 26\nvalue = [0, 0, 2, 1, 18, 5]'),
#  Text(0.875, 0.25, 'x[5] <= 25.5\ngini = 0.31\nsamples = 22\nvalue = [0, 0, 0, 1, 18, 3]'),
#  Text(0.8541666666666666, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.8958333333333334, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.9583333333333334, 0.25, 'x[6] <= 54.0\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 0, 0, 2]'),
#  Text(0.9375, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.9791666666666666, 0.08333333333333333, '\n  (...)  \n')]

# %%
fig.savefig("decistion_tree_classifier.png")

# %%
y_predict= dt.predict(x_test)

# %%
y_predict
# Out:
# array([5, 6, 4, 6, 5, 6, 6, 5, 5, 5, 5, 6, 7, 6, 7, 6, 8, 5, 5, 5, 5, 6,
#        7, 5, 4, 6, 6, 6, 5, 6, 7, 6, 6, 5, 5, 6, 7, 6, 6, 5, 5, 5, 6, 6,
#        5, 5, 6, 6, 6, 6, 5, 6, 5, 7, 6, 4, 5, 7, 5, 5, 5, 6, 5, 6, 5, 6,
#        6, 6, 6, 6, 5, 5, 6, 6, 4, 5, 5, 6, 5, 5, 6, 5, 5, 6, 6, 6, 6, 5,
#        5, 6, 5, 6, 5, 6, 5, 6, 5, 5, 5, 5, 5, 5, 5, 5, 6, 5, 6, 5, 7, 6,
#        5, 6, 6, 5, 5, 8, 5, 6, 5, 5, 6, 6, 6, 6, 5, 6, 5, 6, 6, 6, 5, 6,
#        5, 6, 4, 5, 3, 7, 5, 5, 6, 6, 6, 5, 5, 6, 5, 5, 6, 6, 8, 6, 6, 5,
#        5, 5, 6, 5, 5, 6, 6, 6, 5, 6, 5, 7, 5, 7, 8, 5, 6, 6, 6, 5, 5, 7,
#        5, 6, 6, 5, 5, 6, 5, 6, 6, 5, 5, 6, 5, 7, 6, 6, 6, 8, 5, 6, 5, 6,
#        7, 7, 5, 6, 7, 6, 5, 5, 5, 6, 6, 5, 6, 6, 6, 5, 5, 5, 5, 5, 5, 6,
#        5, 5, 5, 6, 4, 6, 6, 6, 6, 6, 6, 6, 7, 6, 5, 5, 6, 5, 6, 6, 6, 6,
#        6, 5, 6, 4, 6, 5, 6, 6, 6, 7, 5, 7, 6, 8, 5, 7, 5, 5, 8, 6, 3, 5,
#        4, 6, 4, 5, 7, 5, 6, 6, 5, 5, 6, 7, 5, 5, 6, 6, 7, 5, 6, 5, 6, 7,
#        6, 7, 6, 6, 6, 5, 5, 6, 8, 5, 7, 5, 7, 6, 5, 6, 6, 7, 5, 6, 7, 6,
#        5, 6, 7, 5, 7, 6, 6, 6, 3, 6, 5, 7, 6, 5, 6, 6, 7, 7, 7, 5, 6, 7,
#        6, 6, 5, 6, 6, 6, 5, 5, 5, 5])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.4852941176470588

# %%
# Hyperparameter tuning

# %%
grid_param = {
             'criterion': ['gini', 'entropy'],
             'max_depth' : range(2,10,1),  
             'min_samples_leaf' : range(1,8,1),
             'min_samples_split': range(2,8,1),
             'splitter' : ['best', 'random']
    
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(estimator=dt, param_grid= grid_param, cv = 5, verbose=1)

# %%
grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 1344 candidates, totalling 6720 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 10),
#                          'min_samples_leaf': range(1, 8),
#                          'min_samples_split': range(2, 8),
#                          'splitter': ['best', 'random']},
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 5,
#  'min_samples_leaf': 6,
#  'min_samples_split': 7,
#  'splitter': 'random'}

# %%
model_with_best_params = DecisionTreeClassifier(criterion='gini', splitter='random', max_depth=7, min_samples_split=3,  min_samples_leaf=6)

# %%
model_with_best_params.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, min_samples_leaf=6, min_samples_split=3,
#                        splitter='random')

# %%
model_with_best_params.score(x_test,y_test)
# Out:
# 0.5647058823529412

# %%
from sklearn import tree
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(25,15))
tree.plot_tree(model_with_best_params,filled=True,fontsize=10)
# Out:
# [Text(0.7026209677419355, 0.9375, 'x[10] <= 11.053\ngini = 0.65\nsamples = 1019\nvalue = [7, 43, 423, 408, 126, 12]'),
#  Text(0.5221774193548387, 0.8125, 'x[6] <= 108.501\ngini = 0.588\nsamples = 749\nvalue = [7.0, 33.0, 390.0, 276.0, 40.0, 3.0]'),
#  Text(0.6123991935483871, 0.875, 'True  '),
#  Text(0.36693548387096775, 0.6875, 'x[1] <= 0.521\ngini = 0.601\nsamples = 692\nvalue = [7.0, 32.0, 338.0, 272.0, 40.0, 3.0]'),
#  Text(0.23387096774193547, 0.5625, 'x[1] <= 0.405\ngini = 0.61\nsamples = 322\nvalue = [0, 7, 126, 153, 33, 3]'),
#  Text(0.12903225806451613, 0.4375, 'x[10] <= 10.466\ngini = 0.606\nsamples = 165\nvalue = [0.0, 1.0, 46.0, 89.0, 26.0, 3.0]'),
#  Text(0.06451612903225806, 0.3125, 'x[10] <= 9.571\ngini = 0.563\nsamples = 112\nvalue = [0, 1, 36, 64, 9, 2]'),
#  Text(0.03225806451612903, 0.1875, 'x[9] <= 0.658\ngini = 0.52\nsamples = 47\nvalue = [0.0, 1.0, 22.0, 24.0, 0.0, 0.0]'),
#  Text(0.016129032258064516, 0.0625, 'gini = 0.517\nsamples = 34\nvalue = [0, 1, 19, 14, 0, 0]'),
#  Text(0.04838709677419355, 0.0625, 'gini = 0.355\nsamples = 13\nvalue = [0, 0, 3, 10, 0, 0]'),
#  Text(0.0967741935483871, 0.1875, 'x[6] <= 31.877\ngini = 0.555\nsamples = 65\nvalue = [0, 0, 14, 40, 9, 2]'),
#  Text(0.08064516129032258, 0.0625, 'gini = 0.651\nsamples = 28\nvalue = [0, 0, 5, 14, 7, 2]'),
#  Text(0.11290322580645161, 0.0625, 'gini = 0.444\nsamples = 37\nvalue = [0, 0, 9, 26, 2, 0]'),
#  Text(0.1935483870967742, 0.3125, 'x[9] <= 0.722\ngini = 0.639\nsamples = 53\nvalue = [0, 0, 10, 25, 17, 1]'),
#  Text(0.16129032258064516, 0.1875, 'x[10] <= 10.822\ngini = 0.597\nsamples = 23\nvalue = [0, 0, 8, 12, 2, 1]'),
#  Text(0.14516129032258066, 0.0625, 'gini = 0.568\nsamples = 13\nvalue = [0, 0, 6, 6, 1, 0]'),
#  Text(0.1774193548387097, 0.0625, 'gini = 0.58\nsamples = 10\nvalue = [0, 0, 2, 6, 1, 1]'),
#  Text(0.22580645161290322, 0.1875, 'x[7] <= 0.997\ngini = 0.558\nsamples = 30\nvalue = [0, 0, 2, 13, 15, 0]'),
#  Text(0.20967741935483872, 0.0625, 'gini = 0.587\nsamples = 15\nvalue = [0, 0, 2, 8, 5, 0]'),
#  Text(0.24193548387096775, 0.0625, 'gini = 0.444\nsamples = 15\nvalue = [0, 0, 0, 5, 10, 0]'),
#  Text(0.3387096774193548, 0.4375, 'x[9] <= 0.937\ngini = 0.571\nsamples = 157\nvalue = [0.0, 6.0, 80.0, 64.0, 7.0, 0.0]'),
#  Text(0.3225806451612903, 0.3125, 'x[9] <= 0.647\ngini = 0.571\nsamples = 149\nvalue = [0, 5, 74, 63, 7, 0]'),
#  Text(0.2903225806451613, 0.1875, 'x[2] <= 0.465\ngini = 0.534\nsamples = 96\nvalue = [0, 4, 57, 32, 3, 0]'),
#  Text(0.27419354838709675, 0.0625, 'gini = 0.552\nsamples = 84\nvalue = [0.0, 3.0, 46.0, 32.0, 3.0, 0.0]'),
#  Text(0.3064516129032258, 0.0625, 'gini = 0.153\nsamples = 12\nvalue = [0, 1, 11, 0, 0, 0]'),
#  Text(0.3548387096774194, 0.1875, 'x[10] <= 9.646\ngini = 0.549\nsamples = 53\nvalue = [0, 1, 17, 31, 4, 0]'),
#  Text(0.3387096774193548, 0.0625, 'gini = 0.5\nsamples = 14\nvalue = [0, 0, 7, 7, 0, 0]'),
#  Text(0.3709677419354839, 0.0625, 'gini = 0.544\nsamples = 39\nvalue = [0, 1, 10, 24, 4, 0]'),
#  Text(0.3548387096774194, 0.3125, 'gini = 0.406\nsamples = 8\nvalue = [0, 1, 6, 1, 0, 0]'),
#  Text(0.5, 0.5625, 'x[6] <= 10.82\ngini = 0.563\nsamples = 370\nvalue = [7, 25, 212, 119, 7, 0]'),
#  Text(0.4838709677419355, 0.4375, 'gini = 0.716\nsamples = 9\nvalue = [1, 3, 3, 2, 0, 0]'),
#  Text(0.5161290322580645, 0.4375, 'x[10] <= 10.071\ngini = 0.555\nsamples = 361\nvalue = [6.0, 22.0, 209.0, 117.0, 7.0, 0.0]'),
#  Text(0.45161290322580644, 0.3125, 'x[1] <= 0.812\ngini = 0.498\nsamples = 250\nvalue = [4, 15, 164, 65, 2, 0]'),
#  Text(0.41935483870967744, 0.1875, 'x[1] <= 0.574\ngini = 0.488\nsamples = 219\nvalue = [2, 10, 144, 61, 2, 0]'),
#  Text(0.4032258064516129, 0.0625, 'gini = 0.523\nsamples = 39\nvalue = [0, 1, 20, 18, 0, 0]'),
#  Text(0.43548387096774194, 0.0625, 'gini = 0.466\nsamples = 180\nvalue = [2, 9, 124, 43, 2, 0]'),
#  Text(0.4838709677419355, 0.1875, 'x[9] <= 0.482\ngini = 0.537\nsamples = 31\nvalue = [2, 5, 20, 4, 0, 0]'),
#  Text(0.46774193548387094, 0.0625, 'gini = 0.5\nsamples = 8\nvalue = [0, 4, 4, 0, 0, 0]'),
#  Text(0.5, 0.0625, 'gini = 0.476\nsamples = 23\nvalue = [2, 1, 16, 4, 0, 0]'),
#  Text(0.5806451612903226, 0.3125, 'x[7] <= 0.996\ngini = 0.61\nsamples = 111\nvalue = [2.0, 7.0, 45.0, 52.0, 5.0, 0.0]'),
#  Text(0.5483870967741935, 0.1875, 'x[8] <= 3.446\ngini = 0.537\nsamples = 32\nvalue = [0, 1, 8, 20, 3, 0]'),
#  Text(0.532258064516129, 0.0625, 'gini = 0.515\nsamples = 20\nvalue = [0, 0, 4, 13, 3, 0]'),
#  Text(0.5645161290322581, 0.0625, 'gini = 0.542\nsamples = 12\nvalue = [0, 1, 4, 7, 0, 0]'),
#  Text(0.6129032258064516, 0.1875, 'x[5] <= 7.06\ngini = 0.61\nsamples = 79\nvalue = [2, 6, 37, 32, 2, 0]'),
#  Text(0.5967741935483871, 0.0625, 'gini = 0.71\nsamples = 25\nvalue = [2, 4, 11, 6, 2, 0]'),
#  Text(0.6290322580645161, 0.0625, 'gini = 0.535\nsamples = 54\nvalue = [0, 2, 26, 26, 0, 0]'),
#  Text(0.6774193548387096, 0.6875, 'x[10] <= 9.825\ngini = 0.163\nsamples = 57\nvalue = [0, 1, 52, 4, 0, 0]'),
#  Text(0.6612903225806451, 0.5625, 'x[7] <= 0.998\ngini = 0.124\nsamples = 46\nvalue = [0, 1, 43, 2, 0, 0]'),
#  Text(0.6451612903225806, 0.4375, 'x[2] <= 0.234\ngini = 0.19\nsamples = 29\nvalue = [0, 1, 26, 2, 0, 0]'),
#  Text(0.6290322580645161, 0.3125, 'gini = 0.449\nsamples = 7\nvalue = [0, 1, 5, 1, 0, 0]'),
#  Text(0.6612903225806451, 0.3125, 'x[2] <= 0.403\ngini = 0.087\nsamples = 22\nvalue = [0, 0, 21, 1, 0, 0]'),
#  Text(0.6451612903225806, 0.1875, 'gini = 0.153\nsamples = 12\nvalue = [0, 0, 11, 1, 0, 0]'),
#  Text(0.6774193548387096, 0.1875, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.6774193548387096, 0.4375, 'gini = 0.0\nsamples = 17\nvalue = [0, 0, 17, 0, 0, 0]'),
#  Text(0.6935483870967742, 0.5625, 'gini = 0.298\nsamples = 11\nvalue = [0, 0, 9, 2, 0, 0]'),
#  Text(0.8830645161290323, 0.8125, 'x[1] <= 0.451\ngini = 0.642\nsamples = 270\nvalue = [0, 10, 33, 132, 86, 9]'),
#  Text(0.7928427419354839, 0.875, '  False'),
#  Text(0.8145161290322581, 0.6875, 'x[4] <= 0.111\ngini = 0.593\nsamples = 146\nvalue = [0, 3, 7, 67, 64, 5]'),
#  Text(0.7983870967741935, 0.5625, 'x[9] <= 0.784\ngini = 0.599\nsamples = 136\nvalue = [0, 3, 7, 59, 62, 5]'),
#  Text(0.7580645161290323, 0.4375, 'x[6] <= 15.281\ngini = 0.591\nsamples = 105\nvalue = [0, 3, 5, 52, 42, 3]'),
#  Text(0.7258064516129032, 0.3125, 'x[6] <= 10.782\ngini = 0.561\nsamples = 28\nvalue = [0, 2, 1, 7, 17, 1]'),
#  Text(0.7096774193548387, 0.1875, 'x[5] <= 4.914\ngini = 0.406\nsamples = 16\nvalue = [0, 2, 0, 2, 12, 0]'),
#  Text(0.6935483870967742, 0.0625, 'gini = 0.56\nsamples = 10\nvalue = [0, 2, 0, 2, 6, 0]'),
#  Text(0.7258064516129032, 0.0625, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.7419354838709677, 0.1875, 'gini = 0.639\nsamples = 12\nvalue = [0, 0, 1, 5, 5, 1]'),
#  Text(0.7903225806451613, 0.3125, 'x[1] <= 0.21\ngini = 0.55\nsamples = 77\nvalue = [0, 1, 4, 45, 25, 2]'),
#  Text(0.7741935483870968, 0.1875, 'gini = 0.5\nsamples = 6\nvalue = [0, 0, 1, 4, 1, 0]'),
#  Text(0.8064516129032258, 0.1875, 'x[3] <= 4.138\ngini = 0.549\nsamples = 71\nvalue = [0, 1, 3, 41, 24, 2]'),
#  Text(0.7903225806451613, 0.0625, 'gini = 0.527\nsamples = 62\nvalue = [0, 0, 3, 38, 19, 2]'),
#  Text(0.8225806451612904, 0.0625, 'gini = 0.568\nsamples = 9\nvalue = [0, 1, 0, 3, 5, 0]'),
#  Text(0.8387096774193549, 0.4375, 'x[1] <= 0.314\ngini = 0.524\nsamples = 31\nvalue = [0, 0, 2, 7, 20, 2]'),
#  Text(0.8225806451612904, 0.3125, 'gini = 0.298\nsamples = 11\nvalue = [0, 0, 0, 2, 9, 0]'),
#  Text(0.8548387096774194, 0.3125, 'x[7] <= 0.996\ngini = 0.615\nsamples = 20\nvalue = [0, 0, 2, 5, 11, 2]'),
#  Text(0.8387096774193549, 0.1875, 'gini = 0.444\nsamples = 12\nvalue = [0, 0, 0, 4, 8, 0]'),
#  Text(0.8709677419354839, 0.1875, 'gini = 0.719\nsamples = 8\nvalue = [0, 0, 2, 1, 3, 2]'),
#  Text(0.8306451612903226, 0.5625, 'gini = 0.32\nsamples = 10\nvalue = [0, 0, 0, 8, 2, 0]'),
#  Text(0.9516129032258065, 0.6875, 'x[1] <= 0.769\ngini = 0.646\nsamples = 124\nvalue = [0, 7, 26, 65, 22, 4]'),
#  Text(0.9354838709677419, 0.5625, 'x[0] <= 9.721\ngini = 0.606\nsamples = 105\nvalue = [0, 4, 18, 60, 20, 3]'),
#  Text(0.9032258064516129, 0.4375, 'x[1] <= 0.488\ngini = 0.572\nsamples = 85\nvalue = [0.0, 4.0, 13.0, 52.0, 14.0, 2.0]'),
#  Text(0.8870967741935484, 0.3125, 'gini = 0.628\nsamples = 11\nvalue = [0, 0, 2, 4, 5, 0]'),
#  Text(0.9193548387096774, 0.3125, 'x[9] <= 0.751\ngini = 0.539\nsamples = 74\nvalue = [0, 4, 11, 48, 9, 2]'),
#  Text(0.9032258064516129, 0.1875, 'x[4] <= 0.064\ngini = 0.544\nsamples = 61\nvalue = [0, 4, 11, 39, 6, 1]'),
#  Text(0.8870967741935484, 0.0625, 'gini = 0.626\nsamples = 19\nvalue = [0, 2, 7, 9, 1, 0]'),
#  Text(0.9193548387096774, 0.0625, 'gini = 0.464\nsamples = 42\nvalue = [0, 2, 4, 30, 5, 1]'),
#  Text(0.9354838709677419, 0.1875, 'gini = 0.462\nsamples = 13\nvalue = [0, 0, 0, 9, 3, 1]'),
#  Text(0.967741935483871, 0.4375, 'x[3] <= 3.694\ngini = 0.685\nsamples = 20\nvalue = [0, 0, 5, 8, 6, 1]'),
#  Text(0.9516129032258065, 0.3125, 'gini = 0.579\nsamples = 11\nvalue = [0, 0, 1, 5, 5, 0]'),
#  Text(0.9838709677419355, 0.3125, 'gini = 0.667\nsamples = 9\nvalue = [0, 0, 4, 3, 1, 1]'),
#  Text(0.967741935483871, 0.5625, 'gini = 0.715\nsamples = 19\nvalue = [0, 3, 8, 5, 2, 1]')]

# %%
y_prediction2 = model_with_best_params.predict(x_test)

# %%
accuracy_score(y_test,y_prediction2)
# Out:
# 0.5647058823529412
